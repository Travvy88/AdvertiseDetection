# %%
# !gdown --fuzzy https://drive.google.com/file/d/1WJ_Wtd-D9Euqp1PHTTZhOj0Tls55wfbQ/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1WJ_Wtd-D9Euqp1PHTTZhOj0Tls55wfbQ
# To: /content/osld.zip
# 100% 989M/989M [00:07<00:00, 129MB/s]

# %%
# !unzip osld > /dev/null

# %%
# install dependencies: (use cu111 because colab has CUDA 11.1)
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html

# install mmcv-full thus we could use CUDA operators
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |█████████████                   | 834.1 MB 1.8 MB/s eta 0:11:21tcmalloc: large alloc 1147494400 bytes == 0x38f52000 @  0x7f6decef7615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |████████████████▌               | 1055.7 MB 1.3 MB/s eta 0:13:03tcmalloc: large alloc 1434370048 bytes == 0x7d5a8000 @  0x7f6decef7615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
# ...

# %%
# !git clone https://github.com/Travvy88/AdvertiseDetection
# Out:
# Cloning into 'AdvertiseDetection'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 163 (delta 43), reused 146 (delta 26), pack-reused 0
# Receiving objects: 100% (163/163), 11.50 MiB | 9.61 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %%
from AdvertiseDetection.utils.osld2coco import osld2coco_logo

osld2coco_logo('/content/osld/annotations/osld-val.json', '/content/osld/annotations/coco_val.json')
osld2coco_logo('/content/osld/annotations/osld-train.json', '/content/osld/annotations/coco_train.json')
osld2coco_logo('/content/osld/annotations/osld-test.json', '/content/osld/annotations/coco_test.json')
# Out:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>] 1843/1843, 112.7 task/s, elapsed: 16s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>] 15747/15747, 114.5 task/s, elapsed: 138s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>] 2433/2433, 111.6 task/s, elapsed: 22s, ETA:     0s

# %%
from AdvertiseDetection.utils.data import check_coco_dataset

check_coco_dataset('/content/osld/annotations/coco_val.json', 'osld/product-images', 100)

# %%
# !mv osld osld_coco

# %%
# !zip -r osld_coco.zip osld_coco > /dev/null

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp osld_coco.zip /content/drive/MyDrive/Ad\ Detection/data
