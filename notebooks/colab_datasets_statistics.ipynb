# %%
# !gdown --fuzzy https://drive.google.com/file/d/1clo_ijB6vnIIkdQi9-UdUXsJWncaSd4K/view?usp=sharing
# !gdown --fuzzy https://drive.google.com/file/d/1CWa3fgtXWbq5BICvdZr6nhuJrGMuOyPO/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1clo_ijB6vnIIkdQi9-UdUXsJWncaSd4K
# To: /content/openlogo_coco.zip
# 100% 4.58G/4.58G [01:01<00:00, 74.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CWa3fgtXWbq5BICvdZr6nhuJrGMuOyPO
# To: /content/osld_coco.zip
# 100% 991M/991M [00:11<00:00, 84.0MB/s]

# %%
# !unzip openlogo_coco.zip > /dev/null
# !unzip osld_coco.zip > /dev/null

# %%
# !git clone https://github.com/Travvy88/AdvertiseDetection
# Out:
# Cloning into 'AdvertiseDetection'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 168 (delta 45), reused 150 (delta 27), pack-reused 0
# Receiving objects: 100% (168/168), 11.50 MiB | 7.95 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# !python AdvertiseDetection/utils/coco_statistics.py openlogo_coco/train_coco.json
# !python AdvertiseDetection/utils/coco_statistics.py openlogo_coco/test_coco.json
# Out:
# openlogo_coco/train_coco.json
#
# Number of images: 18752
# Number of bboxes: 35263
#
# Mean height: 692
# Mean width: 856
#
# 7572 small bboxes, 21%
# 15590 medium bboxes, 44%
# 12083 large bboxes, 34%
# -------
# openlogo_coco/test_coco.json
#
# Number of images: 8331
# Number of bboxes: 15944
#
# Mean height: 692
# Mean width: 880
#
# 3575 small bboxes, 22%
# 7395 medium bboxes, 46%
# 4966 large bboxes, 31%
# -------

# %%
# !python AdvertiseDetection/utils/coco_statistics.py osld_coco/annotations/coco_train.json
# !python AdvertiseDetection/utils/coco_statistics.py osld_coco/annotations/coco_val.json
# !python AdvertiseDetection/utils/coco_statistics.py osld_coco/annotations/coco_test.json
# Out:
# osld_coco/annotations/coco_train.json
#
# Number of images: 15747
# Number of bboxes: 19938
#
# Mean height: 447
# Mean width: 422
#
# 367 small bboxes, 2%
# 14265 medium bboxes, 72%
# 5298 large bboxes, 27%
# -------
# osld_coco/annotations/coco_val.json
#
# Number of images: 1843
# Number of bboxes: 2112
#
# Mean height: 451
# Mean width: 444
#
# 36 small bboxes, 2%
# 1327 medium bboxes, 63%
# 748 large bboxes, 35%
# -------
# osld_coco/annotations/coco_test.json
#
# Number of images: 2433
# Number of bboxes: 3905
#
# Mean height: 459
# Mean width: 455
#
# 216 small bboxes, 6%
# 2504 medium bboxes, 64%
# 1183 large bboxes, 30%
# -------
